# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_input_images = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels))
    
    z_input = tf.placeholder(tf.float32, (None, z_dim))
    
    learn_rate = tf.placeholder(tf.float32)

    return real_input_images, z_input, learn_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):
        alpha = 0.2

        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same', activation=None)
        relu1 = tf.maximum(alpha * x1, x1)

        x2 = tf.layers.conv2d(relu1, 128, 5, strides=2, padding='same', activation=None)
        bn2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(alpha * bn2, bn2)
#         x2 = tf.nn.dropout(x2, keep_prob=0.8)

        x3 = tf.layers.conv2d(relu2, 256, 5, strides=2, padding='same', activation=None)
        bn3 = tf.layers.batch_normalization(x2, training=True)
        relu3 = tf.maximum(alpha * bn3, bn3)
#         x3 = tf.nn.dropout(x3, keep_prob=0.8)

        #Flatten
        flat = tf.reshape(relu3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)

        return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    with tf.variable_scope('generator', reuse=not is_train):
        alpha = 0.2

        #First fully connected layer
        y1 = tf.layers.dense(z, 7*7*512)

        #conv > batch_norm > leaky relu

        #Reshape to start the convolutional stack
        y1 = tf.reshape(y1, (-1, 7, 7, 512))
        y1 = tf.layers.batch_normalization(y1, training=is_train)
        y1 = tf.maximum(alpha * y1, y1)

        #2nd convolution
        y2 = tf.layers.conv2d_transpose(y1, 256, 5, strides=2, padding='same', kernel_initializer=tf.random_normal_initializer(stddev=0.05), activation=None)
        y2 = tf.layers.batch_normalization(y2, training=is_train)
        y2 = tf.maximum(alpha * y2, y2)
#         y2 = tf.nn.dropout(y2, keep_prob=0.8)
        
        y3 = tf.layers.conv2d_transpose(y2, 128, 5, strides=2, padding='same', kernel_initializer=tf.random_normal_initializer(stddev=0.05), activation=None)
        y3 = tf.layers.batch_normalization(y3, training=is_train)
        y3 = tf.maximum(alpha * y3, y3)
#         y3 = tf.nn.dropout(y3, keep_prob=0.8)
        
        logits = tf.layers.conv2d_transpose(y3, out_channel_dim, 3, strides=1, padding='same', kernel_initializer=tf.random_normal_initializer(stddev=0.05), activation=None)
        
        out =tf.tanh(logits)
        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)
    
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real) * (1 - 0.1)))
    
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_logits_fake)))
    
    d_loss = d_loss_real + d_loss_fake
    
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    train_vars = tf.trainable_variables()
    g_vars = [var for var in train_vars if var.name.startswith('generator')]
    d_vars = [var for var in train_vars if var.name.startswith('discriminator')]
    
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
        
    
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    _, image_width, image_height, image_channels = data_shape
    input_real, z_input, learn_rate = model_inputs(image_width, image_height, image_channels, z_dim)
    d_loss, g_loss = model_loss(input_real, z_input, image_channels)
    d_opt, g_opt = model_opt(d_loss, g_loss, learn_rate, beta1)
    
    
    saver = tf.train.Saver()
    
    steps = 0
    losses = []
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1
                
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                _ = sess.run(d_opt, 
                             feed_dict={input_real: batch_images, z_input: batch_z, learn_rate: learning_rate})
                
                _ = sess.run(g_opt, 
                             feed_dict={input_real: batch_images, z_input: batch_z, learn_rate: learning_rate})
                
                    
                if steps % 10 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_d_loss = d_loss.eval({z_input: batch_z, input_real: batch_images})
                    train_g_loss = g_loss.eval({z_input: batch_z})

                    print("Epoch {}/{}...".format(epoch_i+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_d_loss),
                          "Generator Loss: {:.4f}".format(train_g_loss))
                    # Save losses to view after training
                    losses.append((train_d_loss, train_g_loss))

                if steps % 100 == 0:
                    # show samples
                    show_generator_output(sess, 16, z_input, image_channels, data_image_mode)
        
        saver.save(sess, './generator.ckpt')
        
        return losses

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0005
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.7276... Generator Loss: 1.5781
# Epoch 1/2... Discriminator Loss: 0.5013... Generator Loss: 2.7897
# Epoch 1/2... Discriminator Loss: 0.4115... Generator Loss: 2.7986
# Epoch 1/2... Discriminator Loss: 0.4040... Generator Loss: 2.9876
# Epoch 1/2... Discriminator Loss: 0.3758... Generator Loss: 3.4076
# Epoch 1/2... Discriminator Loss: 0.3685... Generator Loss: 3.4778
# Epoch 1/2... Discriminator Loss: 0.3532... Generator Loss: 3.8788
# Epoch 1/2... Discriminator Loss: 0.3756... Generator Loss: 3.3178
# Epoch 1/2... Discriminator Loss: 0.5284... Generator Loss: 2.4705
# Epoch 1/2... Discriminator Loss: 0.4590... Generator Loss: 2.7461
# Epoch 1/2... Discriminator Loss: 0.4782... Generator Loss: 2.2653
# Epoch 1/2... Discriminator Loss: 0.8442... Generator Loss: 0.9786
# Epoch 1/2... Discriminator Loss: 0.4709... Generator Loss: 2.4113
# Epoch 1/2... Discriminator Loss: 0.4613... Generator Loss: 2.1962
# Epoch 1/2... Discriminator Loss: 0.6234... Generator Loss: 2.1284
# Epoch 1/2... Discriminator Loss: 0.8075... Generator Loss: 1.5066
# Epoch 1/2... Discriminator Loss: 0.6292... Generator Loss: 1.7086
# Epoch 1/2... Discriminator Loss: 0.4575... Generator Loss: 3.0095
# Epoch 1/2... Discriminator Loss: 0.7483... Generator Loss: 1.6083
# Epoch 1/2... Discriminator Loss: 0.6288... Generator Loss: 2.2365
# Epoch 1/2... Discriminator Loss: 0.4748... Generator Loss: 2.7703
# Epoch 1/2... Discriminator Loss: 0.7289... Generator Loss: 1.4984
# Epoch 1/2... Discriminator Loss: 0.8096... Generator Loss: 1.6500
# Epoch 1/2... Discriminator Loss: 0.7204... Generator Loss: 1.4870
# Epoch 1/2... Discriminator Loss: 0.6760... Generator Loss: 1.5976
# Epoch 1/2... Discriminator Loss: 0.6498... Generator Loss: 1.5672
# Epoch 1/2... Discriminator Loss: 0.6756... Generator Loss: 1.4172
# Epoch 1/2... Discriminator Loss: 0.6666... Generator Loss: 1.6542
# Epoch 1/2... Discriminator Loss: 1.5118... Generator Loss: 1.7539
# Epoch 1/2... Discriminator Loss: 0.8446... Generator Loss: 1.3449
# Epoch 1/2... Discriminator Loss: 0.7803... Generator Loss: 1.3747
# Epoch 1/2... Discriminator Loss: 0.7305... Generator Loss: 1.4562
# Epoch 1/2... Discriminator Loss: 0.6402... Generator Loss: 1.8811
# Epoch 1/2... Discriminator Loss: 0.6846... Generator Loss: 1.5457
# Epoch 1/2... Discriminator Loss: 0.4499... Generator Loss: 2.7746
# Epoch 1/2... Discriminator Loss: 0.6591... Generator Loss: 1.8498
# Epoch 1/2... Discriminator Loss: 0.6668... Generator Loss: 1.7195
# Epoch 1/2... Discriminator Loss: 0.6087... Generator Loss: 1.5847
# Epoch 1/2... Discriminator Loss: 1.0251... Generator Loss: 1.2612
# Epoch 1/2... Discriminator Loss: 0.7428... Generator Loss: 1.4478
# Epoch 1/2... Discriminator Loss: 0.8391... Generator Loss: 1.1727
# Epoch 1/2... Discriminator Loss: 0.7767... Generator Loss: 1.2651
# Epoch 1/2... Discriminator Loss: 0.7477... Generator Loss: 1.3997
# Epoch 1/2... Discriminator Loss: 0.8405... Generator Loss: 1.3050
# Epoch 1/2... Discriminator Loss: 0.6381... Generator Loss: 1.7656
# Epoch 1/2... Discriminator Loss: 0.6695... Generator Loss: 1.6654
# Epoch 1/2... Discriminator Loss: 0.6912... Generator Loss: 1.5573
# Epoch 1/2... Discriminator Loss: 0.5511... Generator Loss: 2.1482
# Epoch 1/2... Discriminator Loss: 0.6079... Generator Loss: 1.8372
# Epoch 1/2... Discriminator Loss: 0.7331... Generator Loss: 1.5254
# Epoch 1/2... Discriminator Loss: 0.7549... Generator Loss: 1.8797
# Epoch 1/2... Discriminator Loss: 0.8531... Generator Loss: 1.5138
# Epoch 1/2... Discriminator Loss: 0.7027... Generator Loss: 1.4983
# Epoch 1/2... Discriminator Loss: 0.6001... Generator Loss: 2.0102
# Epoch 1/2... Discriminator Loss: 0.5995... Generator Loss: 2.1877
# Epoch 1/2... Discriminator Loss: 0.6446... Generator Loss: 1.6347
# Epoch 1/2... Discriminator Loss: 0.6032... Generator Loss: 2.1782
# Epoch 1/2... Discriminator Loss: 0.5779... Generator Loss: 2.2415
# Epoch 1/2... Discriminator Loss: 0.5478... Generator Loss: 1.9370
# Epoch 1/2... Discriminator Loss: 0.5546... Generator Loss: 2.2994
# Epoch 1/2... Discriminator Loss: 0.8024... Generator Loss: 2.3316
# Epoch 1/2... Discriminator Loss: 0.5938... Generator Loss: 1.9165
# Epoch 1/2... Discriminator Loss: 0.6661... Generator Loss: 1.9296
# Epoch 1/2... Discriminator Loss: 1.1203... Generator Loss: 1.6934
# Epoch 1/2... Discriminator Loss: 0.7442... Generator Loss: 2.2613
# Epoch 1/2... Discriminator Loss: 0.5555... Generator Loss: 2.3459
# Epoch 1/2... Discriminator Loss: 0.6879... Generator Loss: 2.2499
# Epoch 1/2... Discriminator Loss: 0.7389... Generator Loss: 1.8013
# Epoch 1/2... Discriminator Loss: 0.7561... Generator Loss: 1.2678
# Epoch 1/2... Discriminator Loss: 0.6438... Generator Loss: 1.7716
# Epoch 1/2... Discriminator Loss: 0.9441... Generator Loss: 3.5370
# Epoch 1/2... Discriminator Loss: 0.7216... Generator Loss: 1.8327
# Epoch 1/2... Discriminator Loss: 0.8883... Generator Loss: 1.0550
# Epoch 1/2... Discriminator Loss: 0.7647... Generator Loss: 1.7310
# Epoch 1/2... Discriminator Loss: 0.7370... Generator Loss: 1.6647
# Epoch 1/2... Discriminator Loss: 0.7528... Generator Loss: 1.3274
# Epoch 1/2... Discriminator Loss: 0.7333... Generator Loss: 1.3061
# Epoch 1/2... Discriminator Loss: 0.7225... Generator Loss: 1.6160
# Epoch 1/2... Discriminator Loss: 0.7309... Generator Loss: 1.7865
# Epoch 1/2... Discriminator Loss: 0.5700... Generator Loss: 2.7380
# Epoch 1/2... Discriminator Loss: 1.4845... Generator Loss: 0.4876
# Epoch 1/2... Discriminator Loss: 0.8285... Generator Loss: 1.3369
# Epoch 1/2... Discriminator Loss: 0.7995... Generator Loss: 1.6981
# Epoch 1/2... Discriminator Loss: 0.7788... Generator Loss: 1.6943
# Epoch 1/2... Discriminator Loss: 0.7572... Generator Loss: 1.6321
# Epoch 1/2... Discriminator Loss: 0.7442... Generator Loss: 1.6826
# Epoch 1/2... Discriminator Loss: 0.7189... Generator Loss: 2.0517
# Epoch 1/2... Discriminator Loss: 0.6781... Generator Loss: 1.4585
# Epoch 1/2... Discriminator Loss: 0.7247... Generator Loss: 1.6528
# Epoch 1/2... Discriminator Loss: 0.5181... Generator Loss: 2.5597
# Epoch 1/2... Discriminator Loss: 0.5993... Generator Loss: 2.0413
# Epoch 1/2... Discriminator Loss: 0.4685... Generator Loss: 3.3403
# Epoch 1/2... Discriminator Loss: 0.6811... Generator Loss: 1.6111
# Epoch 2/2... Discriminator Loss: 1.1320... Generator Loss: 2.3190
# Epoch 2/2... Discriminator Loss: 1.2571... Generator Loss: 0.8738
# Epoch 2/2... Discriminator Loss: 0.7961... Generator Loss: 2.3342
# Epoch 2/2... Discriminator Loss: 0.7377... Generator Loss: 1.6799
# Epoch 2/2... Discriminator Loss: 0.8327... Generator Loss: 1.6945
# Epoch 2/2... Discriminator Loss: 0.9387... Generator Loss: 1.0147
# Epoch 2/2... Discriminator Loss: 0.7241... Generator Loss: 1.5600
# Epoch 2/2... Discriminator Loss: 0.5629... Generator Loss: 2.0502
# Epoch 2/2... Discriminator Loss: 0.8444... Generator Loss: 1.6737
# Epoch 2/2... Discriminator Loss: 0.5655... Generator Loss: 2.0298
# Epoch 2/2... Discriminator Loss: 0.5729... Generator Loss: 2.0886
# Epoch 2/2... Discriminator Loss: 0.5897... Generator Loss: 2.1627
# Epoch 2/2... Discriminator Loss: 0.7598... Generator Loss: 1.4042
# Epoch 2/2... Discriminator Loss: 1.6669... Generator Loss: 0.4559
# Epoch 2/2... Discriminator Loss: 0.9219... Generator Loss: 1.5283
# Epoch 2/2... Discriminator Loss: 0.6424... Generator Loss: 2.3405
# Epoch 2/2... Discriminator Loss: 0.6941... Generator Loss: 1.6835
# Epoch 2/2... Discriminator Loss: 0.7992... Generator Loss: 1.2421
# Epoch 2/2... Discriminator Loss: 0.8288... Generator Loss: 1.2710
# Epoch 2/2... Discriminator Loss: 0.7716... Generator Loss: 1.7300
# Epoch 2/2... Discriminator Loss: 1.0684... Generator Loss: 1.2595
# Epoch 2/2... Discriminator Loss: 0.7314... Generator Loss: 1.8749
# Epoch 2/2... Discriminator Loss: 0.5368... Generator Loss: 2.0330
# Epoch 2/2... Discriminator Loss: 0.8454... Generator Loss: 1.9017
# Epoch 2/2... Discriminator Loss: 0.5955... Generator Loss: 2.1838
# Epoch 2/2... Discriminator Loss: 0.6446... Generator Loss: 1.5552
# Epoch 2/2... Discriminator Loss: 0.6757... Generator Loss: 1.6482
# Epoch 2/2... Discriminator Loss: 0.7849... Generator Loss: 1.2179
# Epoch 2/2... Discriminator Loss: 0.5483... Generator Loss: 2.1152
# Epoch 2/2... Discriminator Loss: 0.5321... Generator Loss: 3.0553
# Epoch 2/2... Discriminator Loss: 0.7078... Generator Loss: 1.4493
# Epoch 2/2... Discriminator Loss: 0.4586... Generator Loss: 2.8687
# Epoch 2/2... Discriminator Loss: 4.1572... Generator Loss: 5.0813
# Epoch 2/2... Discriminator Loss: 1.1327... Generator Loss: 0.7798
# Epoch 2/2... Discriminator Loss: 0.9573... Generator Loss: 1.1098
# Epoch 2/2... Discriminator Loss: 0.6657... Generator Loss: 1.9800
# Epoch 2/2... Discriminator Loss: 0.8433... Generator Loss: 1.3255
# Epoch 2/2... Discriminator Loss: 0.7288... Generator Loss: 1.9561
# Epoch 2/2... Discriminator Loss: 0.8157... Generator Loss: 1.3961
# Epoch 2/2... Discriminator Loss: 0.6832... Generator Loss: 1.7838
# Epoch 2/2... Discriminator Loss: 0.6994... Generator Loss: 1.7579
# Epoch 2/2... Discriminator Loss: 0.5222... Generator Loss: 2.2095
# Epoch 2/2... Discriminator Loss: 0.8392... Generator Loss: 1.1585
# Epoch 2/2... Discriminator Loss: 0.9204... Generator Loss: 1.1483
# Epoch 2/2... Discriminator Loss: 0.6233... Generator Loss: 3.5831
# Epoch 2/2... Discriminator Loss: 0.7801... Generator Loss: 1.4689
# Epoch 2/2... Discriminator Loss: 0.8631... Generator Loss: 1.4516
# Epoch 2/2... Discriminator Loss: 0.9140... Generator Loss: 1.1369
# Epoch 2/2... Discriminator Loss: 0.6373... Generator Loss: 1.9019
# Epoch 2/2... Discriminator Loss: 0.6441... Generator Loss: 1.8329
# Epoch 2/2... Discriminator Loss: 0.7036... Generator Loss: 1.5236
# Epoch 2/2... Discriminator Loss: 1.5846... Generator Loss: 0.5673
# Epoch 2/2... Discriminator Loss: 1.0110... Generator Loss: 1.5014
# Epoch 2/2... Discriminator Loss: 0.6824... Generator Loss: 2.0214
# Epoch 2/2... Discriminator Loss: 0.6937... Generator Loss: 1.4806
# Epoch 2/2... Discriminator Loss: 0.7321... Generator Loss: 1.7045
# Epoch 2/2... Discriminator Loss: 1.2452... Generator Loss: 1.1376
# Epoch 2/2... Discriminator Loss: 0.6938... Generator Loss: 1.5952
# Epoch 2/2... Discriminator Loss: 0.7159... Generator Loss: 1.4905
# Epoch 2/2... Discriminator Loss: 0.7656... Generator Loss: 1.2212
# Epoch 2/2... Discriminator Loss: 0.6460... Generator Loss: 1.8634
# Epoch 2/2... Discriminator Loss: 0.6475... Generator Loss: 2.8301
# Epoch 2/2... Discriminator Loss: 0.6239... Generator Loss: 1.7411
# Epoch 2/2... Discriminator Loss: 0.5785... Generator Loss: 1.9169
# Epoch 2/2... Discriminator Loss: 0.8398... Generator Loss: 2.7059
# Epoch 2/2... Discriminator Loss: 0.7773... Generator Loss: 1.3739
# Epoch 2/2... Discriminator Loss: 1.0204... Generator Loss: 2.1019
# Epoch 2/2... Discriminator Loss: 1.0138... Generator Loss: 0.8647
# Epoch 2/2... Discriminator Loss: 0.7363... Generator Loss: 1.4467
# Epoch 2/2... Discriminator Loss: 0.6358... Generator Loss: 1.7930
# Epoch 2/2... Discriminator Loss: 0.7046... Generator Loss: 1.5837
# Epoch 2/2... Discriminator Loss: 0.9115... Generator Loss: 1.0279
# Epoch 2/2... Discriminator Loss: 0.6313... Generator Loss: 2.1045
# Epoch 2/2... Discriminator Loss: 0.6517... Generator Loss: 1.6944
# Epoch 2/2... Discriminator Loss: 0.4331... Generator Loss: 3.5178
# Epoch 2/2... Discriminator Loss: 0.6571... Generator Loss: 2.2955
# Epoch 2/2... Discriminator Loss: 0.8202... Generator Loss: 1.4862
# Epoch 2/2... Discriminator Loss: 0.6868... Generator Loss: 1.9553
# Epoch 2/2... Discriminator Loss: 0.8154... Generator Loss: 1.1489
# Epoch 2/2... Discriminator Loss: 1.2651... Generator Loss: 2.1228
# Epoch 2/2... Discriminator Loss: 1.7144... Generator Loss: 0.6335
# Epoch 2/2... Discriminator Loss: 0.9877... Generator Loss: 1.2076
# Epoch 2/2... Discriminator Loss: 0.8742... Generator Loss: 1.2419
# Epoch 2/2... Discriminator Loss: 0.7879... Generator Loss: 1.7677
# Epoch 2/2... Discriminator Loss: 0.6676... Generator Loss: 1.7022
# Epoch 2/2... Discriminator Loss: 0.7301... Generator Loss: 2.3929
# Epoch 2/2... Discriminator Loss: 0.7668... Generator Loss: 1.6582
# Epoch 2/2... Discriminator Loss: 0.7176... Generator Loss: 1.6545
# Epoch 2/2... Discriminator Loss: 0.6560... Generator Loss: 1.6301
# Epoch 2/2... Discriminator Loss: 0.7808... Generator Loss: 1.3847
# Epoch 2/2... Discriminator Loss: 0.7032... Generator Loss: 1.4339
# Epoch 2/2... Discriminator Loss: 0.7215... Generator Loss: 2.5685
# Epoch 2/2... Discriminator Loss: 0.5774... Generator Loss: 3.8972
# Epoch 2/2... Discriminator Loss: 0.5046... Generator Loss: 2.3884

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0005
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.9793... Generator Loss: 1.0061
# Epoch 1/1... Discriminator Loss: 0.6088... Generator Loss: 1.8202
# Epoch 1/1... Discriminator Loss: 0.5757... Generator Loss: 2.3774
# Epoch 1/1... Discriminator Loss: 0.3865... Generator Loss: 3.2661
# Epoch 1/1... Discriminator Loss: 0.3682... Generator Loss: 3.6040
# Epoch 1/1... Discriminator Loss: 0.3552... Generator Loss: 3.9202
# Epoch 1/1... Discriminator Loss: 0.3427... Generator Loss: 4.5940
# Epoch 1/1... Discriminator Loss: 0.3535... Generator Loss: 4.1522
# Epoch 1/1... Discriminator Loss: 0.3356... Generator Loss: 5.0607
# Epoch 1/1... Discriminator Loss: 0.3392... Generator Loss: 5.0210
# Epoch 1/1... Discriminator Loss: 0.3347... Generator Loss: 5.2673
# Epoch 1/1... Discriminator Loss: 0.3366... Generator Loss: 5.3060
# Epoch 1/1... Discriminator Loss: 0.3356... Generator Loss: 5.2320
# Epoch 1/1... Discriminator Loss: 0.3403... Generator Loss: 5.6335
# Epoch 1/1... Discriminator Loss: 0.3310... Generator Loss: 5.8744
# Epoch 1/1... Discriminator Loss: 0.3449... Generator Loss: 5.9621
# Epoch 1/1... Discriminator Loss: 0.3308... Generator Loss: 5.7835
# Epoch 1/1... Discriminator Loss: 0.3306... Generator Loss: 6.2592
# Epoch 1/1... Discriminator Loss: 0.3295... Generator Loss: 6.4090
# Epoch 1/1... Discriminator Loss: 0.3415... Generator Loss: 6.0699
# Epoch 1/1... Discriminator Loss: 0.3308... Generator Loss: 6.1330
# Epoch 1/1... Discriminator Loss: 0.3300... Generator Loss: 6.1604
# Epoch 1/1... Discriminator Loss: 0.3291... Generator Loss: 6.2172
# Epoch 1/1... Discriminator Loss: 0.3285... Generator Loss: 6.4867
# Epoch 1/1... Discriminator Loss: 0.3320... Generator Loss: 5.8797
# Epoch 1/1... Discriminator Loss: 0.3305... Generator Loss: 6.2069
# Epoch 1/1... Discriminator Loss: 0.3297... Generator Loss: 6.3840
# Epoch 1/1... Discriminator Loss: 0.3322... Generator Loss: 6.3463
# Epoch 1/1... Discriminator Loss: 0.3288... Generator Loss: 6.5780
# Epoch 1/1... Discriminator Loss: 0.3293... Generator Loss: 6.4880
# Epoch 1/1... Discriminator Loss: 0.3299... Generator Loss: 6.2202
# Epoch 1/1... Discriminator Loss: 0.3283... Generator Loss: 6.4167
# Epoch 1/1... Discriminator Loss: 0.3294... Generator Loss: 5.9303
# Epoch 1/1... Discriminator Loss: 0.3352... Generator Loss: 5.1078
# Epoch 1/1... Discriminator Loss: 0.3384... Generator Loss: 5.0395
# Epoch 1/1... Discriminator Loss: 5.0677... Generator Loss: 2.2543
# Epoch 1/1... Discriminator Loss: 1.0369... Generator Loss: 1.1094
# Epoch 1/1... Discriminator Loss: 1.0881... Generator Loss: 1.1619
# Epoch 1/1... Discriminator Loss: 0.9855... Generator Loss: 1.0769
# Epoch 1/1... Discriminator Loss: 0.5252... Generator Loss: 2.1647
# Epoch 1/1... Discriminator Loss: 0.5091... Generator Loss: 2.0973
# Epoch 1/1... Discriminator Loss: 0.7401... Generator Loss: 1.2311
# Epoch 1/1... Discriminator Loss: 0.5728... Generator Loss: 2.0272
# Epoch 1/1... Discriminator Loss: 1.3417... Generator Loss: 0.9660
# Epoch 1/1... Discriminator Loss: 0.9377... Generator Loss: 1.1822
# Epoch 1/1... Discriminator Loss: 0.8029... Generator Loss: 1.3604
# Epoch 1/1... Discriminator Loss: 0.7931... Generator Loss: 1.2556
# Epoch 1/1... Discriminator Loss: 0.8033... Generator Loss: 1.2841
# Epoch 1/1... Discriminator Loss: 0.8556... Generator Loss: 1.4525
# Epoch 1/1... Discriminator Loss: 1.1410... Generator Loss: 0.6565
# Epoch 1/1... Discriminator Loss: 0.6898... Generator Loss: 1.6209
# Epoch 1/1... Discriminator Loss: 0.9070... Generator Loss: 1.5070
# Epoch 1/1... Discriminator Loss: 0.8591... Generator Loss: 1.6923
# Epoch 1/1... Discriminator Loss: 0.8432... Generator Loss: 1.6808
# Epoch 1/1... Discriminator Loss: 0.7944... Generator Loss: 1.3268
# Epoch 1/1... Discriminator Loss: 0.7617... Generator Loss: 1.7110
# Epoch 1/1... Discriminator Loss: 0.7934... Generator Loss: 1.4359
# Epoch 1/1... Discriminator Loss: 0.7493... Generator Loss: 1.3564
# Epoch 1/1... Discriminator Loss: 0.8775... Generator Loss: 1.5362
# Epoch 1/1... Discriminator Loss: 0.8292... Generator Loss: 1.3456
# Epoch 1/1... Discriminator Loss: 0.7510... Generator Loss: 1.5838
# Epoch 1/1... Discriminator Loss: 1.0413... Generator Loss: 1.4413
# Epoch 1/1... Discriminator Loss: 1.1837... Generator Loss: 1.7734
# Epoch 1/1... Discriminator Loss: 0.8460... Generator Loss: 1.5836
# Epoch 1/1... Discriminator Loss: 0.8327... Generator Loss: 1.6109
# Epoch 1/1... Discriminator Loss: 1.0529... Generator Loss: 1.5523
# Epoch 1/1... Discriminator Loss: 0.7091... Generator Loss: 1.3848
# Epoch 1/1... Discriminator Loss: 1.1851... Generator Loss: 1.0673
# Epoch 1/1... Discriminator Loss: 0.8665... Generator Loss: 1.3182
# Epoch 1/1... Discriminator Loss: 0.7025... Generator Loss: 1.3617
# Epoch 1/1... Discriminator Loss: 0.7344... Generator Loss: 1.5338
# Epoch 1/1... Discriminator Loss: 0.9384... Generator Loss: 1.4431
# Epoch 1/1... Discriminator Loss: 0.8691... Generator Loss: 1.5155
# Epoch 1/1... Discriminator Loss: 0.8714... Generator Loss: 1.2476
# Epoch 1/1... Discriminator Loss: 0.8423... Generator Loss: 1.5272
# Epoch 1/1... Discriminator Loss: 0.7162... Generator Loss: 1.3910
# Epoch 1/1... Discriminator Loss: 0.8476... Generator Loss: 1.4622
# Epoch 1/1... Discriminator Loss: 1.1303... Generator Loss: 0.8466
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-97293279c58c> in <module>()
#      13 with tf.Graph().as_default():
#      14     train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
# ---> 15           celeba_dataset.shape, celeba_dataset.image_mode)
#
# <ipython-input-15-4ce122d31032> in train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode)
#      36
#      37                 _ = sess.run(g_opt,
# ---> 38                              feed_dict={input_real: batch_images, z_input: batch_z, learn_rate: learning_rate})
#      39
#      40
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
